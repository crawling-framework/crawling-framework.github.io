# %%
import matplotlib.pyplot as plt
import numpy as np
import re
import json
import os
import math
from sklearn.metrics import auc
from utils import get_percentile, import_graph

METRICS_LIST = ['degrees', 'k_cores', 'eccentricity', 'betweenness_centrality']
graph_names = ['wikivote', 'hamsterster', 'DCAM', 'gnutella', 'github', 'dblp2010']
method_names = ['RC','RW','BFS','DFS','MOD','DE']
METHOD_COLOR = {
    'AFD':'pink',
    'RC':'grey',
    'RW':'green',
    'DFS':'black', 
    'BFS':'blue', 
    'DE':'darkmagenta', 
    'MOD':'orangered'
}
PROPERTIES_COLOR = {
    'degrees': 'g', 
    'k_cores': 'b', 
    'eccentricity': 'r', 
    'betweenness_centrality': 'y'} 


DUMPS_DIR = '../results/dumps_shared'
SEED_COUNT = 8
TOP_PERCENTILE = 10

# %% [markdown]
# Load results into memory

# %%
def load_results(base_dir, graph):
    file_pattern = graph + r'_results_budget(\d+).json'
    budget, filename = None, None
    
    for filename in os.listdir(base_dir):
        match = re.match(file_pattern, filename)
        if match:
            budget = int(match.group(1))
            break
            
    if not budget:
        raise FileNotFoundError
    
    with open(os.path.join(base_dir, filename), 'r') as result_file:
        data = json.load(result_file)
    return data['crawler_avg'], data['history'], int(budget)

# %%
# draw plot 

def draw_nodes_history(history, crawler_avg, print_methods, graph_name, seed_count, budget):
    """
    Drawing history for every method(average are bold) and every seed(thin)
    """
    # TBD - ,graph_name,seed_count are only for filenames. need to clean them
    plt.figure(figsize=(10, 10))
    auc_res = {}
    
    for method, method_data in history.items():
        if method in print_methods:
            auc_res[method] = {}
            for seed_num, seed_data in list(method_data.items())[:seed_count]:
                data = np.array(seed_data['nodes'][:budget])
                auc_res[method][seed_num] = auc(x=np.arange(len(data)), y=data)
                # от
                #plt.plot(data,
                 #        linewidth=0.5,
                  #       color=METHOD_COLOR[method])

    for method, avg_data in crawler_avg.items():
        if method not in print_methods:
            continue
        data = np.array(avg_data['nodes'][:budget])
        auc_res[method]['average'] = auc(x=np.arange(len(data)), y=data)
        plt.plot(data,
                 linewidth=3,
                 color=METHOD_COLOR[method],
                 label=method)

    plt.legend()
    plt.savefig('../results/history/' + graph_name + '_history_' +
                str(seed_count) + '_seeds_' +
                str(budget) + 'iterations.png')
    plt.grid()
    plt.xlabel('iteration number')
    plt.ylabel('node count')
    plt.show()
    return auc_res

    
def draw_properties_history(percentile_set, crawler_avg, print_methods, graph_name, seed_count,
                            budget):
    fig, axs = plt.subplots(2, 2, figsize=(10, 10))
    plt.figure(figsize=(20, 20))
    
    auc_res = {}
    
    for method in print_methods:
        auc_res[method] = {}
        for prop in METRICS_LIST:
            # ремап для красивой отрисовки 2*2
            j = {'degrees': 0, 'k_cores': 1, 'eccentricity': 2, 'betweenness_centrality': 3}[prop] 
            
            data = np.array(crawler_avg[method][prop][:budget]) / seed_count / \
                   len(percentile_set[prop])
            auc_res[method][prop] = auc(x=np.arange(len(data)), y=data)
            axs[j // 2][j % 2].plot(data*8,
                                    label=method,
                                    color=METHOD_COLOR[method])
            axs[j // 2][j % 2].set_title(
                graph_name + ' ' + prop + ' from ' + str(len(percentile_set[prop]))+'nodes')
            axs[j // 2][j % 2].legend()
            axs[j // 2][j % 2].grid(True)
            axs[j // 2][j % 2].set_xlabel('iteration number')
            axs[j // 2][j % 2].set_ylabel('% of top nodes')
            
    fig.savefig('../results/history/' + graph_name + '_scores_' + 
                str(seed_count) + '_seeds_' + 
                str(budget) + 'iterations.png')
    plt.show()
    return auc_res

def plot_graph(graph_name, print_methods, budget_slices):
    crawler_avg, history, max_budget = load_results(DUMPS_DIR, graph_name)
    budget_slices.append(max_budget)
    
    big_graph = import_graph(graph_name)
    # берём топ 10 процентов вершин
    percentile, percentile_set = get_percentile(big_graph, graph_name, TOP_PERCENTILE)    
    
    if graph_name == 'gnutella': # большой костыль.Мы брали не тот эксцентриситет
        percentile_set['eccentricity'] = set(big_graph.nodes()).\
            difference(percentile_set['eccentricity'])
    
    for budget_slice in budget_slices:
        auc_res = draw_nodes_history(history, crawler_avg, print_methods, graph_name, SEED_COUNT, budget_slice)
        print('Nodes AUC for budget: '+ str(budget_slice) + ' ' + str(auc_res))
        
    for budget_slice in budget_slices:
        auc_res = draw_properties_history(percentile_set, crawler_avg, print_methods, graph_name, SEED_COUNT,
                                budget_slice)
        print('Nodes AUC for budget: '+ str(budget_slice) + ' ' + str(auc_res))
    
    
    
    for prop in METRICS_LIST:
        plt.plot([auc_res[i][prop] for i in print_methods], label = prop, color = PROPERTIES_COLOR[prop])
        plt.xticks(range(len(print_methods)),print_methods)
    plt.title('AUC res')
    plt.xlabel('method')
    plt.ylabel('AUC value')
    plt.grid()
    plt.legend()
    plt.show()
    print('Properties AUC: ' + str(auc_res))

# %% [markdown]
# Wikivote nodes: 889 edges: 2914

# %%
plot_graph(graph_names[0], ['RC','RW','BFS','DFS','MOD','DE'], [100])
# Out:
# Nodes AUC for budget: 100 {'RC': {'398': 26637.0, '273': 31309.5, '378': 28045.5, '387': 29811.0, '417': 33728.5, '403': 25035.0, '766': 30380.0, '396': 28696.0, 'average': 29205.3125}, 'MOD': {'417': 31746.0, '766': 34627.5, '396': 31586.5, '378': 31330.0, '398': 32342.0, '273': 32117.0, '403': 31419.5, '387': 32200.0, 'average': 32171.0625}, 'BFS': {'417': 30240.5, '273': 32426.0, '398': 31295.0, '403': 33094.5, '387': 32470.5, '378': 29886.0, '766': 28059.5, '396': 33173.5, 'average': 31330.6875}, 'DE': {'398': 31958.0, '273': 33496.5, '766': 30049.5, '403': 33380.5, '396': 31495.0, '417': 30442.0, '387': 37577.0, '378': 29428.5, 'average': 32228.375}, 'DFS': {'387': 28543.0, '378': 25380.0, '766': 28634.5, '273': 25216.0, '417': 19243.5, '396': 20505.5, '403': 21420.5, '398': 25628.0, 'average': 24321.375}, 'RW': {'396': 32126.5, '273': 32457.5, '403': 26913.5, '417': 26941.0, '387': 34488.0, '398': 29173.5, '766': 23269.5, '378': 32406.0, 'average': 29721.9375}}
# Nodes AUC for budget: 889 {'RC': {'398': 619288.5, '273': 610564.0, '378': 616618.5, '387': 612122.5, '417': 629297.5, '403': 607225.5, '766': 609458.5, '396': 615736.0, 'average': 615038.875}, 'MOD': {'417': 647701.5, '766': 653065.5, '396': 647615.0, '378': 646800.5, '398': 648297.5, '273': 647991.0, '403': 648357.5, '387': 648725.5, 'average': 648569.25}, 'BFS': {'417': 618670.5, '273': 630188.0, '398': 622356.5, '403': 629193.5, '387': 628758.5, '378': 630321.5, '766': 590834.5, '396': 631646.0, 'average': 622746.125}, 'DE': {'398': 642407.5, '273': 643589.0, '766': 638156.5, '403': 639209.5, '396': 636099.0, '417': 640618.5, '387': 653216.5, '378': 637927.5, 'average': 641403.0}, 'DFS': {'387': 638179.5, '378': 631647.5, '766': 637139.5, '273': 635862.0, '417': 632388.5, '396': 633648.0, '403': 629251.5, '398': 636230.5, 'average': 634293.375}, 'RW': {'396': 613283.5, '273': 628562.0, '403': 609090.5, '417': 607216.0, '387': 634348.0, '398': 618475.0, '766': 562800.5, '378': 632219.0, 'average': 613249.3125}}
# Nodes AUC for budget: 100 {'RC': {'degrees': 9.263307005494507, 'k_cores': 9.91664616141732, 'eccentricity': 6.636135912698412, 'betweenness_centrality': 7.713955965909091}, 'RW': {'degrees': 8.761847527472527, 'k_cores': 9.687930610236222, 'eccentricity': 7.3398313492063485, 'betweenness_centrality': 7.730113636363636}, 'BFS': {'degrees': 9.177712912087912, 'k_cores': 9.904281496062993, 'eccentricity': 7.978918650793652, 'betweenness_centrality': 8.182439630681817}, 'DFS': {'degrees': 6.817135989010988, 'k_cores': 6.1360728346456686, 'eccentricity': 5.92562003968254, 'betweenness_centrality': 7.427112926136364}, 'MOD': {'degrees': 9.348901098901099, 'k_cores': 10.711552657480318, 'eccentricity': 7.902926587301587, 'betweenness_centrality': 8.026455965909092}, 'DE': {'degrees': 8.924278846153847, 'k_cores': 10.013287401574804, 'eccentricity': 7.183432539682539, 'betweenness_centrality': 7.7541725852272725}}
# Nodes AUC for budget: 889 {'RC': {'degrees': 107.05442994505495, 'k_cores': 108.31951279527559, 'eccentricity': 100.6170634920635, 'betweenness_centrality': 102.16716974431819}, 'RW': {'degrees': 105.96377060439559, 'k_cores': 107.68571604330708, 'eccentricity': 102.17219742063492, 'betweenness_centrality': 102.27689985795453}, 'BFS': {'degrees': 106.84495192307692, 'k_cores': 108.2693159448819, 'eccentricity': 104.57490079365078, 'betweenness_centrality': 103.8262606534091}, 'DFS': {'degrees': 104.06473214285714, 'k_cores': 103.46518208661418, 'eccentricity': 102.8373511904762, 'betweenness_centrality': 103.88343394886363}, 'MOD': {'degrees': 106.89732142857143, 'k_cores': 109.17778051181102, 'eccentricity': 104.99067460317461, 'betweenness_centrality': 102.50363991477272}, 'DE': {'degrees': 106.48609203296702, 'k_cores': 108.51870078740157, 'eccentricity': 103.34513888888888, 'betweenness_centrality': 102.43226207386363}}
# Properties AUC: {'RC': {'degrees': 107.05442994505495, 'k_cores': 108.31951279527559, 'eccentricity': 100.6170634920635, 'betweenness_centrality': 102.16716974431819}, 'RW': {'degrees': 105.96377060439559, 'k_cores': 107.68571604330708, 'eccentricity': 102.17219742063492, 'betweenness_centrality': 102.27689985795453}, 'BFS': {'degrees': 106.84495192307692, 'k_cores': 108.2693159448819, 'eccentricity': 104.57490079365078, 'betweenness_centrality': 103.8262606534091}, 'DFS': {'degrees': 104.06473214285714, 'k_cores': 103.46518208661418, 'eccentricity': 102.8373511904762, 'betweenness_centrality': 103.88343394886363}, 'MOD': {'degrees': 106.89732142857143, 'k_cores': 109.17778051181102, 'eccentricity': 104.99067460317461, 'betweenness_centrality': 102.50363991477272}, 'DE': {'degrees': 106.48609203296702, 'k_cores': 108.51870078740157, 'eccentricity': 103.34513888888888, 'betweenness_centrality': 102.43226207386363}}

# %% [markdown]
# hamsterster nodes: 2000 edges: 16097

# %%
plot_graph(graph_names[1], ['RC','RW','BFS','DFS','MOD','DE'], [100, 1000])
# Out:
# Nodes AUC for budget: 100 {'RC': {'1176': 66422.5, '425': 48181.0, '1562': 60076.0, '1995': 60076.5, '1581': 67645.5, '999': 73728.5, '835': 64017.0, '973': 68054.5, 'average': 63525.1875}, 'BFS': {'425': 37860.5, '835': 81304.5, '1176': 48713.0, '1562': 63910.0, '999': 51703.5, '1581': 51431.0, '973': 78296.5, '1995': 48347.0, 'average': 57695.75}, 'RW': {'973': 76056.0, '999': 56730.0, '1562': 62571.5, '425': 45474.5, '1581': 51286.0, '835': 82210.0, '1995': 51674.5, '1176': 64925.0, 'average': 61365.9375}, 'MOD': {'1562': 69159.0, '1995': 45760.5, '835': 73405.0, '425': 43141.5, '1176': 57466.0, '1581': 68776.0, '999': 53807.0, '973': 73788.5, 'average': 60662.9375}, 'DFS': {'1995': 69874.0, '835': 72922.5, '973': 70223.5, '1581': 69279.5, '1176': 68791.0, '425': 67491.0, '999': 70020.5, '1562': 60981.0, 'average': 68697.875}, 'DE': {'135': 77516.0, '1704': 62869.5, '864': 78811.5, '110': 73284.5, '1737': 85126.5, '40': 85809.5, '836': 82215.0, '1993': 66762.5, 'average': 76549.375}}
# Nodes AUC for budget: 1000 {'RC': {'1176': 1457821.0, '425': 1407709.0, '1562': 1422330.5, '1995': 1487338.0, '1581': 1448996.0, '999': 1471970.5, '835': 1446626.0, '973': 1454621.5, 'average': 1449676.5625}, 'BFS': {'425': 1385022.5, '835': 1482410.5, '1176': 1483074.5, '1562': 1493979.5, '999': 1364769.5, '1581': 1357021.5, '973': 1430427.5, '1995': 1483186.0, 'average': 1434986.4375}, 'RW': {'973': 1473725.0, '999': 1432719.5, '1562': 1565878.5, '425': 1428879.0, '1581': 1390205.0, '835': 1546194.5, '1995': 1518539.5, '1176': 1526994.5, 'average': 1485391.9375}, 'MOD': {'1562': 1497241.0, '1995': 1487363.0, '835': 1499124.0, '425': 1451439.0, '1176': 1469252.0, '1581': 1491462.0, '999': 1465366.5, '973': 1498076.5, 'average': 1482415.5}, 'DFS': {'1995': 1569329.5, '835': 1542690.0, '973': 1548593.0, '1581': 1547245.5, '1176': 1547034.5, '425': 1548924.0, '999': 1558584.0, '1562': 1549410.0, 'average': 1551476.3125}, 'DE': {'135': 1545420.5, '1704': 1532006.0, '864': 1553027.5, '110': 1538090.0, '1737': 1574134.0, '40': 1574304.0, '836': 1548699.0, '1993': 1562796.5, 'average': 1553559.6875}}
# Nodes AUC for budget: 2000 {'RC': {'1176': 3374814.5, '425': 3302448.5, '1562': 3343302.5, '1995': 3410942.5, '1581': 3361817.5, '999': 3385541.5, '835': 3342275.5, '973': 3388358.0, 'average': 3363687.5625}, 'BFS': {'425': 3291659.5, '835': 3397291.5, '1176': 3396487.5, '1562': 3418210.5, '999': 3254921.5, '1581': 3254182.5, '973': 3323998.0, '1995': 3400236.5, 'average': 3342123.4375}, 'RW': {'973': 3378644.5, '999': 3357230.5, '1562': 3485628.5, '425': 3356147.0, '1581': 3311470.5, '835': 3474787.5, '1995': 3450932.0, '1176': 3445186.5, 'average': 3407503.375}, 'MOD': {'1562': 3397366.5, '1995': 3385959.5, '835': 3394845.5, '425': 3347117.5, '1176': 3364242.5, '1581': 3387399.5, '999': 3361178.5, '973': 3393798.0, 'average': 3378988.4375}, 'DFS': {'1995': 3488804.5, '835': 3450774.5, '973': 3460521.0, '1581': 3460725.5, '1176': 3464492.5, '425': 3458322.5, '999': 3467627.5, '1562': 3461554.5, 'average': 3464102.8125}, 'DE': {'135': 3467908.5, '1704': 3464052.0, '864': 3472747.5, '110': 3449939.5, '1737': 3498820.0, '40': 3505413.0, '836': 3479655.5, '1993': 3481066.5, 'average': 3477450.3125}}
# Nodes AUC for budget: 100 {'RC': {'degrees': 9.655373475609753, 'k_cores': 8.768329326923078, 'eccentricity': 7.780322394459104, 'betweenness_centrality': 8.436533106435645}, 'RW': {'degrees': 8.980335365853659, 'k_cores': 7.941205929487179, 'eccentricity': 7.467410125329816, 'betweenness_centrality': 8.03016707920792}, 'BFS': {'degrees': 8.640891768292684, 'k_cores': 7.767127403846154, 'eccentricity': 7.18618073878628, 'betweenness_centrality': 7.745784344059406}, 'DFS': {'degrees': 9.497827743902437, 'k_cores': 8.38661858974359, 'eccentricity': 8.561881596306069, 'betweenness_centrality': 8.820080445544555}, 'MOD': {'degrees': 8.653086890243902, 'k_cores': 7.591780181623933, 'eccentricity': 6.943106860158311, 'betweenness_centrality': 7.735032487623763}, 'DE': {'degrees': 9.810060975609757, 'k_cores': 8.807859241452991, 'eccentricity': 8.374979386543536, 'betweenness_centrality': 8.786703279702968}}
# Nodes AUC for budget: 1000 {'RC': {'degrees': 122.04946646341463, 'k_cores': 120.14960603632478, 'eccentricity': 117.17457536279682, 'betweenness_centrality': 116.17086943069307}, 'RW': {'degrees': 121.05937500000002, 'k_cores': 117.80879407051283, 'eccentricity': 117.2955969656992, 'betweenness_centrality': 115.91959313118811}, 'BFS': {'degrees': 120.51295731707317, 'k_cores': 115.77821180555556, 'eccentricity': 116.23126236807389, 'betweenness_centrality': 114.56984839108911}, 'DFS': {'degrees': 121.67850609756098, 'k_cores': 116.00577590811966, 'eccentricity': 120.68337730870712, 'betweenness_centrality': 119.09297648514854}, 'MOD': {'degrees': 120.71189024390245, 'k_cores': 116.0807625534188, 'eccentricity': 116.33092843007915, 'betweenness_centrality': 115.69736231435644}, 'DE': {'degrees': 122.22538109756098, 'k_cores': 116.88812099358975, 'eccentricity': 119.70695910290237, 'betweenness_centrality': 117.96526918316832}}
# Nodes AUC for budget: 2000 {'RC': {'degrees': 247.04946646341463, 'k_cores': 245.14960603632477, 'eccentricity': 242.12520613456462, 'betweenness_centrality': 240.58230198019803}, 'RW': {'degrees': 246.05937500000002, 'k_cores': 242.80879407051282, 'eccentricity': 242.2955969656992, 'betweenness_centrality': 240.17535581683168}, 'BFS': {'degrees': 245.5129573170732, 'k_cores': 240.32789129273505, 'eccentricity': 241.2304996701847, 'betweenness_centrality': 238.6639077970297}, 'DFS': {'degrees': 246.67850609756098, 'k_cores': 241.00577590811966, 'eccentricity': 245.68337730870712, 'betweenness_centrality': 243.38637066831689}, 'MOD': {'degrees': 245.71189024390245, 'k_cores': 241.0807625534188, 'eccentricity': 241.33092843007915, 'betweenness_centrality': 239.98452970297032}, 'DE': {'degrees': 247.22538109756098, 'k_cores': 241.88812099358975, 'eccentricity': 244.70695910290237, 'betweenness_centrality': 242.69782642326734}}
# Properties AUC: {'RC': {'degrees': 247.04946646341463, 'k_cores': 245.14960603632477, 'eccentricity': 242.12520613456462, 'betweenness_centrality': 240.58230198019803}, 'RW': {'degrees': 246.05937500000002, 'k_cores': 242.80879407051282, 'eccentricity': 242.2955969656992, 'betweenness_centrality': 240.17535581683168}, 'BFS': {'degrees': 245.5129573170732, 'k_cores': 240.32789129273505, 'eccentricity': 241.2304996701847, 'betweenness_centrality': 238.6639077970297}, 'DFS': {'degrees': 246.67850609756098, 'k_cores': 241.00577590811966, 'eccentricity': 245.68337730870712, 'betweenness_centrality': 243.38637066831689}, 'MOD': {'degrees': 245.71189024390245, 'k_cores': 241.0807625534188, 'eccentricity': 241.33092843007915, 'betweenness_centrality': 239.98452970297032}, 'DE': {'degrees': 247.22538109756098, 'k_cores': 241.88812099358975, 'eccentricity': 244.70695910290237, 'betweenness_centrality': 242.69782642326734}}

# %% [markdown]
# DCAM nodes: 2752 edges: 68741

# %%
plot_graph(graph_names[2], ['RC','RW','BFS','DFS','MOD','DE'], [100, 1000])
# Out:
# Nodes AUC for budget: 100 {'BFS': {'145391693': 119814.5, '131388': 99908.5, '979749': 90763.5, '229006675': 147984.5, '447189805': 134599.5, '20278562': 15188.0, '18770681': 110886.0, '2647636': 85777.0, 'average': 100615.1875}, 'DFS': {'447189805': 70001.0, '18770681': 71435.0, '229006675': 110647.5, '131388': 68601.0, '2647636': 64579.5, '20278562': 18567.5, '145391693': 87200.0, '979749': 64068.0, 'average': 69387.4375}, 'RW': {'18770681': 120325.5, '20278562': 14846.0, '447189805': 121724.0, '979749': 120289.5, '145391693': 96255.0, '2647636': 95933.0, '131388': 121358.5, '229006675': 119564.5, 'average': 101287.0}, 'DE': {'215761115': 138321.0, '37201652': 145755.0, '8544983': 142017.0, '59546961': 134497.5, '33110510': 155660.5, '192337300': 130989.5, '123068327': 132734.5, '135299200': 140122.5, 'average': 140012.1875}, 'RC': {'229006675': 128719.5, '447189805': 131065.0, '145391693': 131945.0, '2647636': 128161.5, '20278562': 14007.5, '979749': 129732.5, '131388': 131180.5, '18770681': 124881.0, 'average': 114961.5625}, 'MOD': {'979749': 71835.0, '20278562': 15200.5, '2647636': 88350.0, '145391693': 119445.5, '131388': 144365.0, '229006675': 142327.5, '447189805': 127541.0, '18770681': 136899.5, 'average': 105745.5}}
# Nodes AUC for budget: 1000 {'BFS': {'145391693': 2081991.0, '131388': 2063331.5, '979749': 2027777.5, '229006675': 2098276.5, '447189805': 2126459.0, '20278562': 1819375.0, '18770681': 1998683.5, '2647636': 2066795.5, 'average': 2035336.1875}, 'DFS': {'447189805': 1952679.5, '18770681': 1952585.5, '229006675': 2004524.0, '131388': 1954537.5, '2647636': 1942007.5, '20278562': 1960448.0, '145391693': 1992959.0, '979749': 1950619.0, 'average': 1963795.0}, 'RW': {'18770681': 2078960.0, '20278562': 1826266.5, '447189805': 2046881.0, '979749': 2082865.5, '145391693': 1988721.5, '2647636': 2029772.5, '131388': 2119296.5, '229006675': 2082967.0, 'average': 2031966.3125}, 'DE': {'215761115': 2115055.5, '37201652': 2115180.0, '8544983': 2117774.0, '59546961': 2103841.0, '33110510': 2149858.5, '192337300': 2079956.5, '123068327': 2104901.5, '135299200': 2102700.5, 'average': 2111158.4375}, 'RC': {'229006675': 2140562.0, '447189805': 2104729.5, '145391693': 2094645.5, '2647636': 2106825.0, '20278562': 1974734.0, '979749': 2120065.0, '131388': 2114857.5, '18770681': 2109117.0, 'average': 2095691.9375}, 'MOD': {'979749': 2017054.0, '20278562': 1895295.5, '2647636': 2048941.5, '145391693': 2059150.5, '131388': 2106321.0, '229006675': 2097432.5, '447189805': 2080529.0, '18770681': 2105665.5, 'average': 2051298.6875}}
# Nodes AUC for budget: 2752 {'BFS': {'145391693': 6484409.0, '131388': 6425708.0, '979749': 6403828.5, '229006675': 6480105.5, '447189805': 6513257.5, '20278562': 6464526.0, '18770681': 6364594.5, '2647636': 6462405.5, 'average': 6449854.3125}, 'DFS': {'447189805': 6414935.5, '18770681': 6393507.5, '229006675': 6456893.5, '131388': 6396407.0, '2647636': 6389015.5, '20278562': 6624304.0, '145391693': 6543227.0, '979749': 6382575.5, 'average': 6450108.1875}, 'RW': {'18770681': 6456555.5, '20278562': 6484814.5, '447189805': 6419806.5, '979749': 6460363.5, '145391693': 6374035.5, '2647636': 6401421.0, '131388': 6486984.0, '229006675': 6460811.5, 'average': 6443099.0}, 'DE': {'215761115': 6530964.0, '37201652': 6523601.0, '8544983': 6525186.0, '59546961': 6514231.5, '33110510': 6558407.5, '192337300': 6491005.0, '123068327': 6541079.5, '135299200': 6547918.0, 'average': 6529049.0625}, 'RC': {'229006675': 6764564.5, '447189805': 6582724.5, '145391693': 6524409.0, '2647636': 6535313.5, '20278562': 6647807.0, '979749': 6563405.5, '131388': 6591104.0, '18770681': 6533045.5, 'average': 6592796.6875}, 'MOD': {'979749': 6419403.5, '20278562': 6557768.0, '2647636': 6451021.5, '145391693': 6461597.0, '131388': 6509466.0, '229006675': 6499817.5, '447189805': 6483864.5, '18770681': 6508048.5, 'average': 6486373.3125}}
# Nodes AUC for budget: 100 {'RC': {'degrees': 9.737045454545456, 'k_cores': 9.475260416666666, 'eccentricity': 6.777531362007168, 'betweenness_centrality': 8.119232954545454}, 'RW': {'degrees': 9.04056818181818, 'k_cores': 8.713441506410257, 'eccentricity': 6.085567876344086, 'betweenness_centrality': 7.588181818181818}, 'BFS': {'degrees': 8.865227272727271, 'k_cores': 8.30292467948718, 'eccentricity': 5.9035506272401435, 'betweenness_centrality': 7.608267045454546}, 'DFS': {'degrees': 5.909971590909091, 'k_cores': 4.430108173076922, 'eccentricity': 3.525957661290323, 'betweenness_centrality': 6.045482954545455}, 'MOD': {'degrees': 9.114801136363637, 'k_cores': 8.728385416666667, 'eccentricity': 6.14119623655914, 'betweenness_centrality': 7.835994318181819}, 'DE': {'degrees': 11.35284090909091, 'k_cores': 11.298617788461538, 'eccentricity': 8.429715501792115, 'betweenness_centrality': 9.470028409090908}}
# Nodes AUC for budget: 1000 {'RC': {'degrees': 121.54815340909092, 'k_cores': 121.2361578525641, 'eccentricity': 104.25934139784947, 'betweenness_centrality': 108.32428977272727}, 'RW': {'degrees': 119.70616477272728, 'k_cores': 119.3293469551282, 'eccentricity': 102.63399977598567, 'betweenness_centrality': 106.15588068181819}, 'BFS': {'degrees': 119.50048295454546, 'k_cores': 118.72754407051283, 'eccentricity': 102.28038194444444, 'betweenness_centrality': 106.54048295454547}, 'DFS': {'degrees': 117.43741477272727, 'k_cores': 115.16211939102564, 'eccentricity': 97.66155353942654, 'betweenness_centrality': 105.59559659090908}, 'MOD': {'degrees': 120.32957386363637, 'k_cores': 119.89525240384616, 'eccentricity': 103.67689292114696, 'betweenness_centrality': 107.25758522727273}, 'DE': {'degrees': 123.85019886363636, 'k_cores': 123.7949719551282, 'eccentricity': 106.08720878136202, 'betweenness_centrality': 108.85133522727273}}
# Nodes AUC for budget: 2752 {'RC': {'degrees': 340.5481534090909, 'k_cores': 340.23615785256413, 'eccentricity': 308.91958445340504, 'betweenness_centrality': 316.51048295454547}, 'RW': {'degrees': 338.7061647727273, 'k_cores': 338.3293469551282, 'eccentricity': 300.4089493727598, 'betweenness_centrality': 307.7842329545455}, 'BFS': {'degrees': 338.5004829545454, 'k_cores': 337.7275440705128, 'eccentricity': 300.14346438172043, 'betweenness_centrality': 308.5468465909091}, 'DFS': {'degrees': 336.43741477272727, 'k_cores': 334.1621193910256, 'eccentricity': 300.3394433243727, 'betweenness_centrality': 310.6318465909091}, 'MOD': {'degrees': 339.32957386363637, 'k_cores': 338.89525240384614, 'eccentricity': 302.9024025537634, 'betweenness_centrality': 309.1136079545455}, 'DE': {'degrees': 342.85019886363636, 'k_cores': 342.7949719551282, 'eccentricity': 302.8854054659498, 'betweenness_centrality': 309.1258806818182}}
# Properties AUC: {'RC': {'degrees': 340.5481534090909, 'k_cores': 340.23615785256413, 'eccentricity': 308.91958445340504, 'betweenness_centrality': 316.51048295454547}, 'RW': {'degrees': 338.7061647727273, 'k_cores': 338.3293469551282, 'eccentricity': 300.4089493727598, 'betweenness_centrality': 307.7842329545455}, 'BFS': {'degrees': 338.5004829545454, 'k_cores': 337.7275440705128, 'eccentricity': 300.14346438172043, 'betweenness_centrality': 308.5468465909091}, 'DFS': {'degrees': 336.43741477272727, 'k_cores': 334.1621193910256, 'eccentricity': 300.3394433243727, 'betweenness_centrality': 310.6318465909091}, 'MOD': {'degrees': 339.32957386363637, 'k_cores': 338.89525240384614, 'eccentricity': 302.9024025537634, 'betweenness_centrality': 309.1136079545455}, 'DE': {'degrees': 342.85019886363636, 'k_cores': 342.7949719551282, 'eccentricity': 302.8854054659498, 'betweenness_centrality': 309.1258806818182}}

# %% [markdown]
# gnutella nodes: 36682 edges: 88328

# %%
plot_graph(graph_names[3], ['RC','RW','BFS','DFS','MOD','DE'], [100, 1000, 10000])
# Out:
# Nodes AUC for budget: 100 {'RW': {'31551': 40162.5, '34098': 35516.0, '27103': 44265.5, '897': 50707.0, '19469': 43940.5, '15290': 45182.5, '24157': 42045.5, '15410': 43489.5, 'average': 43163.625}, 'RC': {'34098': 37926.0, '24157': 50385.0, '897': 51051.0, '19469': 43885.0, '27103': 46813.0, '15290': 45999.0, '15410': 43495.0, '31551': 39768.5, 'average': 44915.3125}, 'BFS': {'18935': 43036.0, '427': 32032.5, '11970': 40338.5, '682': 48724.5, '18677': 48836.5, '15471': 48949.0, '20227': 45573.0, '12967': 48104.5, 'average': 44449.3125}, 'DFS': {'7653': 57444.5, '13386': 68274.5, '17990': 64532.0, '28829': 70152.0, '7833': 64211.0, '26847': 67343.5, '34822': 56447.0, '6955': 66666.0, 'average': 64383.8125}, 'MOD': {'34822': 48388.5, '6955': 54708.0, '13386': 55518.5, '28829': 52804.0, '26847': 46666.0, '7653': 50671.5, '17990': 50896.5, '7833': 50153.0, 'average': 51225.75}, 'DE': {'15161': 53268.5, '5440': 50671.5, '3161': 47373.5, '19100': 53790.5, '15853': 52625.0, '22902': 57386.0, '30792': 51715.5, '29594': 48744.0, 'average': 51946.8125}}
# Nodes AUC for budget: 1000 {'RW': {'31551': 3761132.5, '34098': 3873624.5, '27103': 3846614.5, '897': 4112807.0, '19469': 4008657.0, '15290': 4020823.0, '24157': 3922597.0, '15410': 3835919.0, 'average': 3922771.8125}, 'RC': {'34098': 3854926.0, '24157': 4133641.5, '897': 3881451.5, '19469': 3853809.5, '27103': 3867208.5, '15290': 4065598.0, '15410': 4032439.0, '31551': 3802471.5, 'average': 3936443.1875}, 'BFS': {'18935': 3800874.0, '427': 3883910.5, '11970': 3879045.5, '682': 3861556.0, '18677': 4077291.5, '15471': 3649732.5, '20227': 4049061.5, '12967': 3966462.5, 'average': 3895991.75}, 'DFS': {'7653': 4639026.0, '13386': 4674995.5, '17990': 4676302.0, '28829': 4723477.0, '7833': 4668248.0, '26847': 4682723.0, '34822': 4661468.0, '6955': 4639123.0, 'average': 4670670.3125}, 'MOD': {'34822': 4306205.5, '6955': 4368065.0, '13386': 4308226.5, '28829': 4331682.0, '26847': 4355718.5, '7653': 4379769.0, '17990': 4302639.5, '7833': 4394328.0, 'average': 4343329.25}, 'DE': {'15161': 4376204.5, '5440': 4303145.5, '3161': 4250208.0, '19100': 4324070.5, '15853': 4297204.0, '22902': 4383191.0, '30792': 4407135.0, '29594': 4260537.0, 'average': 4325211.9375}}
# /home/denisaivazov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# /home/denisaivazov/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Nodes AUC for budget: 10000 {'RW': {'31551': 188175670.0, '34098': 188335685.5, '27103': 187187320.5, '897': 187856416.0, '19469': 188343104.5, '15290': 188728114.5, '24157': 188306421.0, '15410': 188695831.5, 'average': 188203570.4375}, 'RC': {'34098': 173340139.0, '24157': 173909126.5, '897': 173870484.0, '19469': 173979090.5, '27103': 173914136.0, '15290': 172670268.0, '15410': 176243625.0, '31551': 174142026.0, 'average': 174008611.875}, 'BFS': {'18935': 185904748.5, '427': 187083331.5, '11970': 185115951.5, '682': 188736785.5, '18677': 185620490.0, '15471': 187219175.0, '20227': 185827367.5, '12967': 185401808.5, 'average': 186363707.25}, 'DFS': {'7653': 201195491.0, '13386': 202426290.5, '17990': 202382888.0, '28829': 201356140.0, '7833': 202182430.0, '26847': 202283364.5, '34822': 201681622.0, '6955': 201418512.0, 'average': 201865842.25}, 'MOD': {'34822': 215295294.5, '6955': 215354696.0, '13386': 214965783.0, '28829': 215255042.5, '26847': 215404161.5, '7653': 215313692.5, '17990': 215225419.5, '7833': 215414908.5, 'average': 215278624.75}, 'DE': {'15161': 212978393.5, '5440': 213096124.0, '3161': 212754957.0, '19100': 213008102.5, '15853': 212759771.0, '22902': 213737922.0, '30792': 213476908.0, '29594': 213360438.0, 'average': 213146577.0}}
# Nodes AUC for budget: 36646 {'RW': {'31551': 1114151027.0, '34098': 1114456484.5, '27103': 1112927241.0, '897': 1114334243.5, '19469': 1113957165.0, '15290': 1115227136.0, '24157': 1117241639.5, '15410': 1116200105.0, 'average': 1114811880.1875}, 'RC': {'34098': 1037708075.0, '24157': 1037337715.0, '897': 1039999348.5, '19469': 1038814353.5, '27103': 1037737688.5, '15290': 1037243307.0, '15410': 1042467833.5, '31551': 1039073839.0, 'average': 1038797770.0}, 'BFS': {'18935': 1106859097.0, '427': 1108494898.5, '11970': 1107960719.0, '682': 1112267024.0, '18677': 1108392127.0, '15471': 1109456636.0, '20227': 1109439771.0, '12967': 1105585285.5, 'average': 1108556944.75}, 'DFS': {'7653': 1144956125.5, '13386': 1146742847.0, '17990': 1146678950.5, '28829': 1145174476.0, '7833': 1146290343.5, '26847': 1146705359.0, '34822': 1145417707.0, '6955': 1145374651.5, 'average': 1145917557.5}, 'MOD': {'34822': 1179815238.0, '6955': 1179865448.5, '13386': 1179485526.0, '28829': 1179776818.0, '26847': 1179909719.0, '7653': 1179830394.5, '17990': 1179748904.5, '7833': 1179929024.5, 'average': 1179795134.125}, 'DE': {'15161': 1159514821.5, '5440': 1160771903.0, '3161': 1159891586.0, '19100': 1160902479.0, '15853': 1161069386.0, '22902': 1162763964.5, '30792': 1160781210.0, '29594': 1161695231.0, 'average': 1160923822.625}}
# /home/denisaivazov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# Properties AUC: {'RC': {'degrees': 4417.8254566727055, 'k_cores': 4357.718614186011, 'eccentricity': 3543.3531968018337, 'betweenness_centrality': 4422.988509398881}, 'RW': {'degrees': 4424.059742980073, 'k_cores': 4378.113768183097, 'eccentricity': 3802.638351346327, 'betweenness_centrality': 4429.56281983488}, 'BFS': {'degrees': 4425.509880736715, 'k_cores': 4373.093636555373, 'eccentricity': 3781.30268225045, 'betweenness_centrality': 4433.377002166348}, 'DFS': {'degrees': 4435.349214975846, 'k_cores': 4376.321445348451, 'eccentricity': 3908.7402359739126, 'betweenness_centrality': 4457.518247646015}, 'MOD': {'degrees': 4450.543538647343, 'k_cores': 4396.730526670672, 'eccentricity': 4024.29710652254, 'betweenness_centrality': 4468.553924160753}, 'DE': {'degrees': 4450.164190821256, 'k_cores': 4395.975772382146, 'eccentricity': 3959.9268086046227, 'betweenness_centrality': 4468.409975010234}}

# %% [markdown]
# github nodes: 120865 edges: 439858

# %%
plot_graph(graph_names[4], ['RC','RW','BFS','DFS','MOD','DE'], [100, 1000, 10000, 100000])
# Out:
# Nodes AUC for budget: 100 {'DFS': {'17161': 922373.5, '109528': 909040.5, '14272': 927897.5, '38075': 917882.0, '12741': 940535.0, '83843': 878244.5, '75352': 934284.0, '15640': 915681.0, 'average': 918242.25}, 'MOD': {'36983': 1108662.0, '49211': 1146501.0, '29633': 1116974.0, '73126': 1137478.5, '34745': 1131172.0, '69293': 1150594.5, '92222': 1119286.0, '51709': 1050290.5, 'average': 1120119.8125}, 'BFS': {'74040': 524659.5, '54556': 534416.5, '18850': 708060.0, '64502': 699583.5, '60730': 612469.5, '10581': 690812.5, '45841': 699677.0, '4454': 500598.5, 'average': 621284.625}, 'RW': {'49161': 337843.5, '50673': 603614.5, '63497': 370122.0, '20712': 584125.0, '94799': 411298.0, '30631': 279099.5, '89739': 377923.5, '11683': 608570.5, 'average': 446574.5625}, 'DE': {'112090': 1082675.5, '16026': 994499.5, '54105': 946947.0, '34132': 996347.0, '82146': 1082876.5, '24681': 441884.5, '38078': 967955.0, '32': 968276.5, 'average': 935182.6875}, 'RC': {'63497': 315753.0, '94799': 370634.5, '49161': 453545.5, '11683': 353674.5, '30631': 276407.5, '89739': 318053.0, '50673': 341183.5, '20712': 398894.5, 'average': 353518.25}}
# Nodes AUC for budget: 1000 {'DFS': {'17161': 23639029.5, '109528': 23410784.0, '14272': 23529714.0, '38075': 23351981.5, '12741': 23467407.5, '83843': 23456506.0, '75352': 23528945.5, '15640': 23450145.5, 'average': 23479314.1875}, 'MOD': {'36983': 26681186.5, '49211': 26775031.0, '29633': 26717000.5, '73126': 26804853.0, '34745': 26740827.5, '69293': 26773408.0, '92222': 26680772.5, '51709': 26593105.0, 'average': 26720773.0}, 'BFS': {'74040': 13151773.5, '54556': 13343460.5, '18850': 15981740.0, '64502': 17939752.5, '60730': 16817583.5, '10581': 20007669.0, '45841': 16586201.0, '4454': 17315262.0, 'average': 16392930.25}, 'RW': {'49161': 19510520.0, '50673': 18585018.5, '63497': 17424174.0, '20712': 18657985.5, '94799': 18093424.0, '30631': 17540955.0, '89739': 17839238.5, '11683': 18340411.0, 'average': 18248965.8125}, 'DE': {'112090': 26522816.5, '16026': 26410832.5, '54105': 26230778.5, '34132': 26389353.5, '82146': 26582801.0, '24681': 25526289.0, '38078': 26394886.5, '32': 26476299.0, 'average': 26316757.0625}, 'RC': {'63497': 11900647.5, '94799': 12283506.0, '49161': 13111995.0, '11683': 11667683.5, '30631': 11863785.5, '89739': 12351305.5, '50673': 11693064.5, '20712': 12705024.0, 'average': 12197126.4375}}
# /home/denisaivazov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# Nodes AUC for budget: 10000 {'DFS': {'17161': 555961347.5, '109528': 554855502.5, '14272': 555144770.5, '38075': 554960468.5, '12741': 556501936.5, '83843': 553626803.5, '75352': 555608904.5, '15640': 555543651.5, 'average': 555275423.125}, 'MOD': {'36983': 574289630.5, '49211': 574329479.0, '29633': 574269080.5, '73126': 574428301.0, '34745': 574335332.0, '69293': 574356848.0, '92222': 574229704.5, '51709': 574094848.0, 'average': 574291652.9375}, 'BFS': {'74040': 478702755.5, '54556': 472260843.0, '18850': 486206419.5, '64502': 479523560.5, '60730': 496542923.5, '10581': 495959939.5, '45841': 459442921.5, '4454': 493690248.0, 'average': 482791201.375}, 'RW': {'49161': 495785870.0, '50673': 492132187.0, '63497': 490301766.0, '20712': 489117060.0, '94799': 487445765.5, '30631': 495116952.5, '89739': 486816778.5, '11683': 492205996.0, 'average': 491115296.9375}, 'DE': {'112090': 573984387.5, '16026': 573795202.5, '54105': 573610391.0, '34132': 574035094.0, '82146': 574274126.0, '24681': 572757715.0, '38078': 574048272.5, '32': 574049200.0, 'average': 573819298.5625}, 'RC': {'63497': 345063678.0, '94799': 348595349.5, '49161': 350559730.5, '11683': 339906512.0, '30631': 344906937.0, '89739': 356482146.5, '50673': 345432662.0, '20712': 343297314.5, 'average': 346780541.25}}
# Nodes AUC for budget: 100000 {'DFS': {'17161': 9910224099.0, '109528': 9901465402.0, '14272': 9901680859.5, '38075': 9898339512.0, '12741': 9905368011.5, '83843': 9904473654.0, '75352': 9908648932.5, '15640': 9905502933.0, 'average': 9904462925.4375}, 'MOD': {'36983': 10228864491.0, '49211': 10228846584.5, '29633': 10228776023.0, '73126': 10228937955.5, '34745': 10228878652.5, '69293': 10228902601.0, '92222': 10228727004.5, '51709': 10228654114.5, 'average': 10228823428.3125}, 'BFS': {'74040': 9729999445.5, '54556': 9736121035.5, '18850': 9801691453.0, '64502': 9790309648.5, '60730': 9742581621.0, '10581': 9789800949.0, '45841': 9735742971.5, '4454': 9734153171.5, 'average': 9757550036.9375}, 'RW': {'49161': 9769912209.0, '50673': 9755165750.5, '63497': 9768271308.5, '20712': 9764722698.5, '94799': 9749148119.5, '30631': 9766713710.0, '89739': 9755868080.0, '11683': 9744783119.5, 'average': 9759323124.4375}, 'DE': {'112090': 10015564716.0, '16026': 10015067282.0, '54105': 10005116320.0, '34132': 10016649898.0, '82146': 10003777526.5, '24681': 10011596912.0, '38078': 10006445818.0, '32': 10016396671.5, 'average': 10011326893.0}, 'RC': {'63497': 8640187395.5, '94799': 8643353561.5, '49161': 8629751208.0, '11683': 8626696420.0, '30631': 8622360268.0, '89739': 8656195373.5, '50673': 8626836492.5, '20712': 8601647745.0, 'average': 8630878558.0}}
# Nodes AUC for budget: 120865 {'DFS': {'17161': 12398624591.5, '109528': 12390145696.5, '14272': 12390268206.0, '38075': 12386456771.0, '12741': 12394218942.5, '83843': 12392629892.5, '75352': 12397278058.0, '15640': 12393806942.5, 'average': 12392928637.5625}, 'MOD': {'36983': 12725145141.0, '49211': 12725127233.5, '29633': 12725056672.0, '73126': 12725217739.5, '34745': 12725159301.5, '69293': 12725183250.0, '92222': 12725007653.5, '51709': 12724934763.5, 'average': 12725103969.3125}, 'BFS': {'74040': 12224933982.5, '54556': 12230627867.0, '18850': 12295904000.0, '64502': 12285151440.5, '60730': 12237577986.5, '10581': 12284937703.0, '45841': 12230166835.0, '4454': 12229024483.5, 'average': 12252290537.25}, 'RW': {'49161': 12264717851.5, '50673': 12250297196.0, '63497': 12263224032.5, '20712': 12259732167.5, '94799': 12244141689.0, '30631': 12261991184.0, '89739': 12250806027.5, '11683': 12239639697.0, 'average': 12254318730.625}, 'DE': {'112090': 12504091473.5, '16026': 12502196884.5, '54105': 12491661404.0, '34132': 12504038724.5, '82146': 12489536102.5, '24681': 12499503705.0, '38078': 12494275675.0, '32': 12504223677.0, 'average': 12498690955.75}, 'RC': {'63497': 11110569471.5, '94799': 11112351378.5, '49161': 11100330475.5, '11683': 11097944884.5, '30631': 11095985160.5, '89739': 11127747692.5, '50673': 11095728598.0, '20712': 11073723145.5, 'average': 11101797600.8125}}
# /home/denisaivazov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
# Properties AUC: {'RC': {'degrees': 14963.338091571668, 'k_cores': 14980.40409074804, 'eccentricity': 13837.690105442074, 'betweenness_centrality': 14493.708622254282}, 'RW': {'degrees': 15046.528015700336, 'k_cores': 15064.556960811913, 'eccentricity': 14870.896299919394, 'betweenness_centrality': 14788.131831332217}, 'BFS': {'degrees': 15035.315764944433, 'k_cores': 15052.89048242506, 'eccentricity': 14854.745942508094, 'betweenness_centrality': 14769.22847894432}, 'DFS': {'degrees': 15069.47992448619, 'k_cores': 15085.497460345967, 'eccentricity': 14927.923219065451, 'betweenness_centrality': 14850.075889902373}, 'MOD': {'degrees': 15075.850449073507, 'k_cores': 15090.018511080803, 'eccentricity': 15020.286373943964, 'betweenness_centrality': 14880.218389979935}, 'DE': {'degrees': 15074.41840575713, 'k_cores': 15088.666057942455, 'eccentricity': 15017.559579107487, 'betweenness_centrality': 14863.31060811719}}

# %% [markdown]
# dblp2010 nodes: 226413 edges: 716460

# %%
plot_graph(graph_names[5], ['RC','RW','BFS','DFS','MOD'], [100, 1000, 10000, 100000])
